# %%
import os
import tensorflow as tf
import keras
import cv2
import numpy as np

# %%
pictures = os.listdir("images/")

# %%
pictures
# Out:
# ['image_id_000.jpg',
#  'image_id_001.jpg',
#  'image_id_002.jpg',
#  'image_id_003.jpg',
#  'image_id_004.jpg',
#  'image_id_005.jpg',
#  'image_id_006.jpg',
#  'image_id_007.jpg',
#  'image_id_008.jpg',
#  'image_id_009.jpg',
#  'image_id_010.jpg',
#  'image_id_011.jpg',
#  'image_id_012.jpg',
#  'image_id_013.jpg',
#  'image_id_014.jpg',
#  'image_id_015.jpg',
#  'image_id_016.jpg',
#  'image_id_017.jpg',
#  'image_id_018.jpg',
#  'image_id_019.jpg',
#  'image_id_020.jpg',
#  'image_id_021.jpg',
#  'image_id_022.jpg',
#  'image_id_023.jpg',
#  'image_id_024.jpg',
#  'image_id_025.jpg',
#  'image_id_026.jpg',
#  'image_id_027.jpg',
#  'image_id_028.jpg',
#  'image_id_029.jpg',
#  'image_id_030.jpg',
#  'image_id_031.jpg',
#  'image_id_032.jpg',
#  'image_id_033.jpg',
#  'image_id_034.jpg',
#  'image_id_035.jpg',
#  'image_id_036.jpg',
#  'image_id_037.jpg',
#  'image_id_038.jpg',
#  'image_id_039.jpg',
#  'image_id_040.jpg',
#  'image_id_041.jpg',
#  'image_id_042.jpg',
# ...

# %%
pictures = pictures[:5]

# %%
len(pictures)
# Out:
# 5

# %%
path = "train"
print(os.path.join(path, pictures[0]))
# Out:
# train\image_id_000.jpg

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread(os.path.join(path, pictures[0]), cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(image)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
new_images = list()

# %%
for picture in pictures:
    img_path = os.path.join(path, picture)
    image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (126, 126))
    new_images.append(image)

# %%
len(new_images)
# Out:
# 5

# %%
new_images[0].shape
# Out:
# (126, 126)

# %%
plt.imshow(new_images[4])

# %%
import albumentations as a

# %%
transformation = a.Compose([
    a.RandomCrop(width = 58, height = 58),
    a.HorizontalFlip(p = 0.5),
    a.RandomBrightnessContrast(p = 0.5)
])

# %%
img_1 = transformation(image = new_images[0])["image"]

# %%
plt.imshow(img_1)

# %%
img_2 = transformation(image = new_images[0])["image"]
plt.imshow(img_2)

# %%
img_3 = transformation(image = new_images[4])["image"]
plt.imshow(img_3)
